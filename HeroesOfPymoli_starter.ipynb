# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# import dependencies
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
purchase_data = "C:/Users/melis/Desktop/Panda-Challenge/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
df=pd.read_csv(purchase_data)
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
df.drop_duplicates('SN')
# Out:
#      Purchase ID              SN  Age                 Gender  Item ID  \
# 0              0         Lisim78   20                   Male      108
# 1              1     Lisovynya38   40                   Male      143
# 2              2      Ithergue48   24                   Male       92
# 3              3   Chamassasya86   24                   Male      100
# 4              4       Iskosia90   23                   Male      131
# 5              5         Yalae81   22                   Male       81
# 6              6       Itheria73   36                   Male      169
# 7              7     Iskjaskst81   20                   Male      162
# 8              8       Undjask33   22                   Male       21
# 9              9     Chanosian48   35  Other / Non-Disclosed      136
# 10            10       Inguron55   23                   Male       95
# 11            11    Haisrisuir60   23                   Male      162
# ...

# %% [markdown]
# ## Player Count

# %%
#Display the total number of players
Total_Players=len(df.drop_duplicates('SN'))
totalplayers = pd.DataFrame({'Total_Players':[Total_Players]})
totalplayers
# Out:
#    Total_Players
# 0            576

# %%
Total_Items=len(df.drop_duplicates('Item Name'))
print("Total_Unique_Items:", Total_Items)
Average_price=df.loc[:, "Price"].mean()
print("Average_price:", Average_price)
Total_Number_of_Purchases =len(df ['Item Name'])
print("Number_of_Purchases:", Total_Number_of_Purchases)
# Out:
# Total_Unique_Items: 179
# Average_price: 3.050987179487176
# Number_of_Purchases: 780

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Average purchase total by gender 
avg_purchase_total = gender_stats["Price"].sum()

# Average purchase total by gender divivded by purchase count by unique shoppers
avg_purchase_per_person = avg_purchase_total/total_count_gender

# Create data frame with obtained values 
gender_demographics = pd.DataFrame({"Purchase Count": purchase_count, 
                                    "Average Purchase Price": avg_purchase_price,
                                    "Average Purchase Value":avg_purchase_total,
                                    "Avg Purchase Total per Person": avg_purchase_per_person})

# Provide index in top left as "Gender"
gender_demographics.index.name = "Gender"

# Format with currency style
gender_demographics.style.format({"Average Purchase Value":"${:,.2f}",
                                  "Average Purchase Price":"${:,.2f}",
                                  "Avg Purchase Total per Person":"${:,.2f}"})
Out[5]:
Purchase Count	Average Purchase Price	Average Purchase Va

# %%
#Display the total number of players
purchasing_analysis = pd.DataFrame({'Total Unique Items':[Total_Items], "Average_Price": [Average_price], "Number_of_Purchases": [Total_Number_of_Purchases]})
purchasing_analysis
# Out:
#    Total Unique Items  Average_Price  Number_of_Purchases
# 0                 179       3.050987                  780

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#Gender demographics
df['Gender'].value_counts()
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
#Group by gender and count
Male_count = (df['Gender'].value_counts()['Male'])
Female_count = (df['Gender'].value_counts()['Female'])
Non_Disclosed_count = (df['Gender'].value_counts()['Other / Non-Disclosed'])
Gender_count=duplicate["Gender"].count()

#percentages
Male_Percentage=(Male_count/Gender_count)*100
Female_Percentage=(Female_count/Gender_count)*100
Non_Disclosed_Percentage = (Non_Disclosed_count/Gender_count)*100

#New Df with gender info
Gender_DF=pd.DataFrame({" ":["Male", "Female", "Non_Disclosed_count"], "Percentage of Players": [Male_Percentage, Female_Percentage, Non_Disclosed_Percentage], "Total Count": [Male_count, Female_count, Non_Disclosed_count]})
Gender_DF
# Out:
#                         Percentage of Players  Total Count
# 0                 Male             113.194444          652
# 1               Female              19.618056          113
# 2  Non_Disclosed_count               2.604167           15

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#Establish bins for ages
bins=[0, 10, 15, 20, 25, 30, 35, 40, 200]
binLab=['Under 10', '10-14', '15-19', '20-24', '25-29', '30-35', '35-49', 'Over 40']

#Create new Df
bins_df=df.copy()

#Categorize existing players using age bins (use pd.cut())
bins_df['Age Group'] = pd.cut(bins_df['Age'], bins, labels=binLab)
group_bin = bins_df.groupby(["Age Group"])

#Numbers and percentage by age group
binnerCount = group_bin['SN'].count()
countTotal = df['SN'].count()
percentage = (binnerCount/countTotal)*100
percentage

#Create summary table
Age_Percentage = pd.DataFrame({"Total Count": binnerCount, "Percentage of Players": percentage})
Age_Percentage["Percentage of Players"] = Age_Percentage["Percentage of Players"].map("{:.2f}%".format)

#Display table
Age_Percentage
# Out:
#            Total Count Percentage of Players
# Age Group
# Under 10            32                 4.10%
# 10-14               54                 6.92%
# 15-19              200                25.64%
# 20-24              325                41.67%
# 25-29               77                 9.87%
# 30-35               52                 6.67%
# 35-49               33                 4.23%
# Over 40              7                 0.90%

# %%
# Counting by age group
age_grouped=bins_df.groupby("Age Group")
purchase_count_age = age_grouped["Purchase ID"].count()
average_purchase_price_age = age_grouped["Price"].mean() 
total_purchase_value = age_grouped["Price"].sum()
total_count_age = bins_df["SN"].count()
average_purchase_pp_age = total_purchase_value/total_count_age

# Dataframe
age_demographics = pd.DataFrame({"Purchase Count": purchase_count_age,
                                 "Average Purchase Price": average_purchase_price_age,
                                 "Total Purchase Value":total_purchase_value,
                                 "Average Purchase Total per Person": average_purchase_pp_age})

#Formatting
age_demographics.index.name = None

# Currency
age_demographics.style.format({"Average Purchase Price":"${:,.2f}",
                               "Total Purchase Value":"${:,.2f}",
                               "Average Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_179cf002_9b7e_11e9_90fe_48452016118c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Average Purchase Total per Person</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_179cf002_9b7e_11e9_90fe_48452016118clevel0_row0" class="row_heading level0 row0" >Under 10</th>
#                         <td id="T_179cf002_9b7e_11e9_90fe_48452016118crow0_col0" class="data row0 col0" >32</td>
#                         <td id="T_179cf002_9b7e_11e9_90fe_48452016118crow0_col1" class="data row0 col1" >$3.40</td>
#                         <td id="T_179cf002_9b7e_11e9_90fe_48452016118crow0_col2" class="data row0 col2" >$108.96</td>
# ...

# %% [markdown]
# ## Purchasing Analysis (Age)

# %%
# Bin the purchase_data data frame by age
bins=[0, 10, 15, 20, 25, 30, 35, 40, 200]
binLab=['Under 10', '10-14', '15-19', '20-24', '25-29', '30-35', '35-49', 'Over 40']
binColumn=pd.cut(bins_df["Age"], bins, labels=binLab)

# Basic Calculations
bins_df=df.copy()
bins_df['Age Group'] = pd.cut(bins_df['Age'], bins, labels=binLab)
binColumn = pd.cut(bins_df['Age'], bins, labels=binLab)
grouped_bin = bins_df.groupby(["Age Group"])

#grouped_df=df.groupby(["Age"]).count()
purchase_count_pp=grouped_bin["Age"].count()
purchase_mean_price_pp=grouped_bin["Price"].mean()
purchase_total_value_pp=grouped_bin["Price"].sum()

# Average purchase total by gender divivded by purchase count by unique shoppers
average_purchase_pp = purchase_total_value_pp/purchase_total_value_pp

# Create data frame with obtained values 
gender_demographics = pd.DataFrame({"Purchase Count": purchase_count_pp, 
                                    "Average Purchase Price": purchase_mean_price_pp,
                                    "Average Purchase Value":purchase_total_value_pp,
                                    "Average Purchase Total per Person": average_purchase_pp})

# Index as "Gender"
gender_demographics.index.name = "Gender"

# Currency $
gender_demographics.style.format({"Average Purchase Value":"${:,.2f}",
                                  "Average Purchase Price":"${:,.2f}",
                                  "Average Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_f8a8a6d2_9b90_11e9_9a8e_48452016118c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Average Purchase Value</th>        <th class="col_heading level0 col3" >Average Purchase Total per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f8a8a6d2_9b90_11e9_9a8e_48452016118clevel0_row0" class="row_heading level0 row0" >Under 10</th>
#                         <td id="T_f8a8a6d2_9b90_11e9_9a8e_48452016118crow0_col0" class="data row0 col0" >32</td>
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Group purchase data by screen names
spender_stats = df.groupby("SN")

# Basic Calculations
purchase_count_spender = spender_stats["Purchase ID"].count()
average_purchase_price_spender = spender_stats["Price"].mean() 
purchase_total_spender = spender_stats["Price"].sum()

# Create df
top_spenders = pd.DataFrame({"Purchase Count": purchase_count_spender,
                             "Average Purchase Price": average_purchase_price_spender,
                             "Total Purchase Value":purchase_total_spender})

# Descending order w top 5 spender 
formatted_spenders = top_spenders.sort_values(["Total Purchase Value"], ascending=False).head()

# Formatting $
formatted_spenders.style.format({"Average Purchase Total":"${:,.2f}",
                                 "Average Purchase Price":"${:,.2f}", 
                                 "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_b4eedcd2_9b7b_11e9_a161_48452016118c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b4eedcd2_9b7b_11e9_a161_48452016118clevel0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_b4eedcd2_9b7b_11e9_a161_48452016118crow0_col0" class="data row0 col0" >5</td>
#                         <td id="T_b4eedcd2_9b7b_11e9_a161_48452016118crow0_col1" class="data row0 col1" >$3.79</td>
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Dataframe
items = df[["Item ID", "Item Name", "Price"]]

# Group by item id and item name 
item_df = items.groupby(["Item ID","Item Name"])

# Counting times is purchased
purchase_count_item = item_df["Price"].count()

# Purchase value per item 
purchase_value = (item_df["Price"].sum()) 

# Item price
item_price = purchase_value/purchase_count_item 

# Find individual item price
item_price = purchase_value/purchase_count_item

# Create data frame with obtained values
most_popular_items = pd.DataFrame({"Purchase Count": purchase_count_item, "Item Price": item_price, "Total Purchase Value":purchase_value})

#Descending order/top 5 spenders
popular_formatted = most_popular_items.sort_values(["Purchase Count"], ascending=False).head()

# Currency $
popular_formatted.style.format({"Item Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3f115390_9b81_11e9_8e52_48452016118c" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f115390_9b81_11e9_8e52_48452016118clevel0_row0" class="row_heading level0 row0" >178</th>
#                         <th id="T_3f115390_9b81_11e9_8e52_48452016118clevel1_row0" class="row_heading level1 row0" >Oathbreaker, Last Hope of the Breaking Storm</th>
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
#Most popular items by purchase descending order 
most_popular_items = pd.DataFrame({"Purchase Count": purchase_count_item, 
                                  "Item Price": item_price,
                                   "Total Purchase Value":purchase_value})
popular_descending = most_popular_items.sort_values(["Total Purchase Value"],
                                                   ascending=False).head()
# Currency $
popular_descending.style.format({"Item Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3e1d5282_9b80_11e9_81bf_48452016118c" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3e1d5282_9b80_11e9_81bf_48452016118clevel0_row0" class="row_heading level0 row0" >178</th>
#                         <th id="T_3e1d5282_9b80_11e9_81bf_48452016118clevel1_row0" class="row_heading level1 row0" >Oathbreaker, Last Hope of the Breaking Storm</th>
# ...
